# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjusriram16/Assignment_PythonEssentials_LetsUpgrade/blob/main/Day_2_Assignment_1_Python_LetsUpgrade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# String functions

a= " Sanju Sriram "
b=" Sriram "

print(len(a))
print(len(b))

print(a[2:4])
print(b[5:7])

print(a.upper())
print(b.upper())

print(a.lower())
print(b.lower())

print(a.strip())
print(b.strip())

print(a.split( ))
print(b.split())

a = a.upper();
b = b.lower();

print(a.isupper())
print(a.islower())
print(b.isupper())
print(b.islower())

# List functions

c= ['a', 1, 'c', 3.0, 'b', 2 ]

print(len(a))

print(c[2:])

c.append('d')
print(c)

c.insert(7, 4.0)
print(c)

c.remove(1)
print(c)

c.pop(2);
print(c)

c.pop(3)
print(c)

c.pop()
print(c)

c.sort();
print(c)

c.sort(reverse= True)
print(c)

# Tuple functions

d= ("Sanju", "Sriram", "Python", "LetsUpgrade", 2)

print(d)

print(len(d))

print(d[1:3])

e= list(d)
e.insert(4, "Day")
d= tuple(e)
print(d)

(FirstName, LastName, Course, Platform, Session, SessionNumber)= d

print(FirstName)
print(Course)


print(d.count(2))

print(d.index("LetsUpgrade"))
# Out:
# 14
# 8
# an
# am
#  SANJU SRIRAM
#  SRIRAM
#  sanju sriram
#  sriram
# Sanju Sriram
# Sriram
# ['Sanju', 'Sriram']
# ['Sriram']
# True
# False
# False
# True
# 14
# ['c', 3.0, 'b', 2]
# ['a', 1, 'c', 3.0, 'b', 2, 'd']
# ['a', 1, 'c', 3.0, 'b', 2, 'd', 4.0]
# ['a', 'c', 3.0, 'b', 2, 'd', 4.0]
# ['a', 'c', 'b', 2, 'd', 4.0]
# ['a', 'c', 'b', 'd', 4.0]
# ['a', 'c', 'b', 'd']
# ['a', 'b', 'c', 'd']
# ['d', 'c', 'b', 'a']
# ('Sanju', 'Sriram', 'Python', 'LetsUpgrade', 2)
# 5
# ('Sriram', 'Python')
# ('Sanju', 'Sriram', 'Python', 'LetsUpgrade', 'Day', 2)
# Sanju
# Python
# 1
# 3
