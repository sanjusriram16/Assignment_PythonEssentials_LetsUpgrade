# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjusriram16/Assignment_PythonEssentials_LetsUpgrade/blob/main/Day_6_Python_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install emails
# Out:
# ...
#      |████████████████████████████████| 61kB 5.4MB/s
# ...
#      |████████████████████████████████| 409kB 9.0MB/s
# ...

# %%
import emails

text = '''<p>Hello <span style="color: rgb(226, 80, 65);">Sanju</span></p>
<p>How are you? It&apos;s so long we have met each other. Ping me whenever you get holidays. Take care.</p>
<p><br></p>
<p>Yours lovingly,</p>
<p><span style="color: rgb(147, 101, 184);">Sanju Sriram</span></p>'''

def email(mailId):
  message = emails.html(html=text, subject="Automated Python email", mail_from=('Sanju Sriram', 'xyz'))

  mail_via_python = message.send(to=mailId, 
                               smtp={'host': 'smtp.gmail.com', 
                                     'timeout': 5,
                                    'port':587,
                                    'user':'xyz@gmail.com',
                                    'password':'xyz',
                                    'tls':True})

email("zyx@gmail.com")

# %% [markdown]
# ![mail.jpg](data:image/jpeg;base64,...)
